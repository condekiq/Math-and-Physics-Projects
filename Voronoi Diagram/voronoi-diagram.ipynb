# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Complex grid for Newton basin / Voronoi-like plot (roots of z^3 + c)
X = np.linspace(-3.0, 3.0, 1000)
Y = np.linspace(-1.5, 1.5, 1000)
c = 0.1 * 1j

X_grid, Y_grid = np.meshgrid(X, Y)
Z_grid = X_grid + Y_grid * 1j


def f(z):
    """Polynomial f(z) = z^3 + c."""
    return z * z * z + c


def df(z):
    """Derivative f'(z) = 3z^2."""
    return 3 * z * z


def find_root(z0, num_iters):
    """Newton iteration: find a root of f starting at z0 (num_iters steps)."""
    if num_iters == 0:
        return z0
    z1 = z0 - f(z0) / df(z0)
    return find_root(z1, num_iters - 1)

# %%
Z_hit = np.round(find_root(Z_grid, 50), 5)
Z_unique, Z_counts = np.unique(Z_hit, return_counts=True)

# %%
# Color each point by which root it converged to (Voronoi-like: color = angle of root)
colors = np.angle(Z_unique)
# Vectorized: for each grid point, find index of nearest root and assign that color
distances = np.abs(Z_hit[:, :, np.newaxis] - Z_unique)
k_indices = np.argmin(distances, axis=2)
Z_colored = colors[k_indices]

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.pcolormesh(X_grid, Y_grid, Z_colored)
ax.grid(True)
